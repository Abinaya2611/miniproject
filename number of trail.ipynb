# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    height, width, _ = frame.shape

    # Calculate center box
    box_w = width // 3
    box_h = height // 3

    center_x1 = width // 2 - box_w // 2
    center_y1 = height // 2 - box_h // 2
    center_x2 = center_x1 + box_w
    center_y2 = center_y1 + box_h

    # Draw rectangles for directions
    cv2.rectangle(frame, (0, 0), (100, 100), (255, 255, 255), 2)  # Up
    cv2.putText(frame, "Up", (center_x1 + 10, center_y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    cv2.rectangle(frame, (center_x1, center_y2), (center_x2, height), (255, 255, 255), 2)  # Down
    cv2.putText(frame, "Down", (center_x1 + 10, center_y2 + 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    cv2.rectangle(frame, (0, center_y1), (center_x1, center_y2), (255, 255, 255), 2)  # Left
    cv2.putText(frame, "Left", (center_x1 - 80, center_y1 + 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    cv2.rectangle(frame, (center_x2, center_y1), (width, center_y2), (255, 255, 255), 2)  # Right
    cv2.putText(frame, "Right", (center_x2 + 10, center_y1 + 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    cv2.rectangle(frame, (100, 100), (200, 200), (0, 255, 255), 2)  # Center
    cv2.putText(frame, "Center", (center_x1 + 10, center_y1 + 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)

    cv2.imshow("5-Zone Frame", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    height, width, _ = frame.shape
    cx, cy, = width // 3, height // 3

    # Define polygon points
    left_poly = np.array([[0, 0], [cx, cy - 100], [cx, cy + 100], [0, height]], np.int32)
    right_poly = np.array([[width, 0], [cx, cy - 100], [cx, cy + 100], [width, height]], np.int32)
    up_poly = np.array([[0, 0], [width, 0], [cx, cy - 100], [cx, cy - 100]], np.int32)
    down_poly = np.array([[0, height], [width, height], [cx, cy + 100], [cx, cy + 100]], np.int32)

    # Draw polygons
    cv2.polylines(frame, [left_poly], True, (0, 255, 255), 2)
    cv2.polylines(frame, [right_poly], True, (255, 0, 255), 2)
    cv2.polylines(frame, [up_poly], True, (255, 255, 0), 2)
    cv2.polylines(frame, [down_poly], True, (0, 255, 0), 2)

    # Add Labels
    cv2.putText(frame, "Left", (30, cy), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
    cv2.putText(frame, "Right", (width - 150, cy), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 255), 2)
    cv2.putText(frame, "Up", (cx - 40, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)
    cv2.putText(frame, "Down", (cx - 50, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    cv2.imshow("Polygon Zones", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    overlay = frame.copy()
    if not ret:
        break

    height, width, _ = frame.shape
    cx, cy, = width // 3, height // 3

    # Define polygon points
    left_poly = np.array([[0, 0], [200,150], [200,340], [0,height]], np.int32)
    right_poly = np.array([[width,0],[430, 150], [430,340], [width,height]], np.int32)
    up_poly = np.array([[0, 0], [200,150], [430,150], [width,0]], np.int32)
    down_poly = np.array([[0, height], [200,340], [430,340], [width,height]], np.int32)

    # Draw polygons
    cv2.rectangle(frame, (200, 150), (430, 340), (0, 255, 255), 2) # Center
    
    cv2.polylines(frame, [left_poly], True, (0, 255, 255), 2)
    cv2.polylines(frame, [right_poly], True, (255, 0, 255), 2)
    cv2.polylines(frame, [up_poly], True, (255, 255, 0), 2)
    cv2.polylines(frame, [down_poly], True, (0, 255, 0), 2)

    # Add Labels
    cv2.putText(frame, "Center", (cx+50, cy + 80), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)       
    cv2.putText(frame, "Left", (30, cy+60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
    cv2.putText(frame, "Right", (width - 150, cy+60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 255), 2)
    cv2.putText(frame, "Up", (cx+60 , 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)
    cv2.putText(frame, "Down", (cx +50, height - 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    
    cv2.imshow("Polygon Zones", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    height, width, _ = frame.shape
    cx, cy = width // 2, height // 2

    # Define rectangle boundary (center zone)
    rect_w, rect_h = 230, 190
    rect_x1, rect_y1 = cx - rect_w // 2, cy - rect_h // 2
    rect_x2, rect_y2 = cx + rect_w // 2, cy + rect_h // 2

    # Define polygon points dynamically
    left_poly = np.array([[0, 0], [rect_x1, rect_y1], [rect_x1, rect_y2], [0, height]], np.int32)
    right_poly = np.array([[width, 0], [rect_x2, rect_y1], [rect_x2, rect_y2], [width, height]], np.int32)
    up_poly = np.array([[0, 0], [rect_x1, rect_y1], [rect_x2, rect_y1], [width, 0]], np.int32)
    down_poly = np.array([[0, height], [rect_x1, rect_y2], [rect_x2, rect_y2], [width, height]], np.int32)

    # Draw center rectangle
    cv2.rectangle(frame, (rect_x1, rect_y1), (rect_x2, rect_y2), (0, 255, 255), 2)

    # Draw polygon zones
    cv2.polylines(frame, [left_poly], True, (0, 255, 255), 2)
    cv2.polylines(frame, [right_poly], True, (255, 0, 255), 2)
    cv2.polylines(frame, [up_poly], True, (255, 255, 0), 2)
    cv2.polylines(frame, [down_poly], True, (0, 255, 0), 2)

    # Add Labels (positioned for clarity)
    cv2.putText(frame, "Center", (cx - 50, cy + 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
    cv2.putText(frame, "Left", (30, cy), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
    cv2.putText(frame, "Right", (width - 150, cy), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 255), 2)
    cv2.putText(frame, "Up", (cx - 30, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)
    cv2.putText(frame, "Down", (cx - 50, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    cv2.imshow("Polygon Zones", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import mediapipe as mp
import pyautogui
import time

# Initialize
cap = cv2.VideoCapture(0)
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Cooldown
last_action_time = time.time()
cooldown = 1  # seconds

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    height, width, _ = frame.shape
    cx, cy = width // 2, height // 2

    # Define zones
    left_poly = np.array([[0, 0], [200, 150], [200, 340], [0, height]], np.int32)
    right_poly = np.array([[width, 0], [430, 150], [430, 340], [width, height]], np.int32)
    up_poly = np.array([[0, 0], [200, 150], [430, 150], [width, 0]], np.int32)
    down_poly = np.array([[0, height], [200, 340], [430, 340], [width, height]], np.int32)

    # Draw regions
    cv2.rectangle(frame, (200, 150), (430, 340), (0, 255, 255), 2)  # Center
    cv2.polylines(frame, [left_poly], True, (0, 255, 255), 2)
    cv2.polylines(frame, [right_poly], True, (255, 0, 255), 2)
    cv2.polylines(frame, [up_poly], True, (255, 255, 0), 2)
    cv2.polylines(frame, [down_poly], True, (0, 255, 0), 2)

    # Labels
    cv2.putText(frame, "Center", (cx, cy + 80), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
    cv2.putText(frame, "Left", (30, cy + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
    cv2.putText(frame, "Right", (width - 150, cy + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 255), 2)
    cv2.putText(frame, "Up", (cx + 60, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)
    cv2.putText(frame, "Down", (cx + 50, height - 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    # Detect hands
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = hands.process(rgb)

    if result.multi_hand_landmarks:
        for handLms in result.multi_hand_landmarks:
            mp_draw.draw_landmarks(frame, handLms, mp_hands.HAND_CONNECTIONS)

            # Get center of hand
            h, w, _ = frame.shape
            lm = handLms.landmark[9]  # Wrist midpoint
            hand_x, hand_y = int(lm.x * w), int(lm.y * h)

            # Show center
            cv2.circle(frame, (hand_x, hand_y), 10, (255, 0, 0), -1)

            # Zone detection
            now = time.time()
            if now - last_action_time > cooldown:
                if cv2.pointPolygonTest(left_poly, (hand_x, hand_y), False) >= 0:
                    pyautogui.press('left')
                    last_action_time = now
                    print("Left")
                elif cv2.pointPolygonTest(right_poly, (hand_x, hand_y), False) >= 0:
                    pyautogui.press('right')
                    last_action_time = now
                    print("Right")
                elif cv2.pointPolygonTest(up_poly, (hand_x, hand_y), False) >= 0:
                    pyautogui.press('up')
                    last_action_time = now
                    print("Up")
                elif cv2.pointPolygonTest(down_poly, (hand_x, hand_y), False) >= 0:
                    pyautogui.press('down')
                    last_action_time = now
                    print("Down")
                elif 200 <= hand_x <= 430 and 150 <= hand_y <= 340:
                    print("Center")
                    last_action_time = now
                    # No keypress for center, or define one if needed

    cv2.imshow("Subway Surfer Gesture Control", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Center
# Center
# Up
# Up
# Right
# Right
# Center
# Right
# Down
# Down
# Center
# Left
# Left
# Center
# Center
# Center
# Center
# Left
# Center
# Left
# Center
# Center
# Left
# Left
# Left
# Center
# Center
# Left
# Center
# Left
# Center
# Center

# %%
import cv2
import numpy as np
import mediapipe as mp
import pyautogui
import time

# Initialize
cap = cv2.VideoCapture(0)
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Cooldown
last_action_time = 0
last_action = None
cooldown = 1  # seconds

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    height, width, _ = frame.shape
    cx, cy = width // 2, height // 2

    # Define zones
    left_poly = np.array([[0, 0], [200, 150], [200, 340], [0, height]], np.int32)
    right_poly = np.array([[width, 0], [430, 150], [430, 340], [width, height]], np.int32)
    up_poly = np.array([[0, 0], [200, 150], [430, 150], [width, 0]], np.int32)
    down_poly = np.array([[0, height], [200, 340], [430, 340], [width, height]], np.int32)
    center_rect = (200, 150, 230, 190)  # x, y, w, h

    # Make a copy for transparency overlay
    overlay = frame.copy()

    # Detect hands
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = hands.process(rgb)

    now = time.time()
    action = None

    if result.multi_hand_landmarks:
        for handLms in result.multi_hand_landmarks:
            mp_draw.draw_landmarks(frame, handLms, mp_hands.HAND_CONNECTIONS)

            # Get center of hand (landmark 9 = base of middle finger)
            lm = handLms.landmark[9]
            hand_x, hand_y = int(lm.x * width), int(lm.y * height)
            cv2.circle(frame, (hand_x, hand_y), 10, (255, 0, 0), -1)

            # Determine action zone
            if cv2.pointPolygonTest(left_poly, (hand_x, hand_y), False) >= 0:
                action = 'left'
                cv2.fillPoly(overlay, [left_poly], (0, 255, 255))
            elif cv2.pointPolygonTest(right_poly, (hand_x, hand_y), False) >= 0:
                action = 'right'
                cv2.fillPoly(overlay, [right_poly], (255, 0, 255))
            elif cv2.pointPolygonTest(up_poly, (hand_x, hand_y), False) >= 0:
                action = 'up'
                cv2.fillPoly(overlay, [up_poly], (255, 255, 0))
            elif cv2.pointPolygonTest(down_poly, (hand_x, hand_y), False) >= 0:
                action = 'down'
                cv2.fillPoly(overlay, [down_poly], (0, 255, 0))
            elif 200 <= hand_x <= 430 and 150 <= hand_y <= 340:
                action = 'center'
                cv2.rectangle(overlay, (200, 150), (430, 340), (0, 255, 255), -1)

    # Blend overlay with transparency
    alpha = 0.4
    frame = cv2.addWeighted(overlay, alpha, frame, 1 - alpha, 0)

    # Draw outlines and labels
    cv2.rectangle(frame, (200, 150), (430, 340), (0, 255, 255), 2)
    cv2.polylines(frame, [left_poly], True, (0, 255, 255), 2)
    cv2.polylines(frame, [right_poly], True, (255, 0, 255), 2)
    cv2.polylines(frame, [up_poly], True, (255, 255, 0), 2)
    cv2.polylines(frame, [down_poly], True, (0, 255, 0), 2)

    cv2.putText(frame, "Center", (cx, cy + 80), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
    cv2.putText(frame, "Left", (30, cy + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
    cv2.putText(frame, "Right", (width - 150, cy + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 255), 2)
    cv2.putText(frame, "Up", (cx + 60, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)
    cv2.putText(frame, "Down", (cx + 50, height - 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    # Perform action with cooldown
    if action and (now - last_action_time > cooldown or action != last_action):
        if action != 'center':  # Only send key for directions
            pyautogui.press(action)
        print(f"Action: {action}")
        last_action_time = now
        last_action = action

    # Show frame
    cv2.imshow("Subway Surfer Gesture Control", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Action: center
# Action: right
# Action: center
# Action: left
# Action: center
# Action: left
# Action: up
# Action: center
# Action: down
# Action: center
# Action: right
# Action: center
# Action: center
# Action: left
# Action: center
# Action: up
# Action: center
# Action: right
# Action: down
# Action: center
# Action: left
# Action: center
# Action: up
# Action: center
# Action: right
# Action: center
# Action: down
# Action: center
# Action: left
# Action: center
# Action: up
# Action: center
# Action: right
# Action: center
# Action: down
# Action: center
# Action: left
# Action: center
# Action: up
# Action: right
# Action: center
# Action: down
# Action: center
# Action: down
# Action: center
# Action: down
# Action: center
# Action: down
# Action: center
# Action: down
# Action: center
# Action: down
# Action: center
# Action: right
# Action: center
# Action: center
# Action: center
# Action: right
# Action: center
# Action: center
# Action: center
# Action: center
# ...

# %%
import cv2
import numpy as np
import mediapipe as mp
import pyautogui
import time

# Initialize webcam and MediaPipe Hands
cap = cv2.VideoCapture(0)
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Cooldown setup
last_action_time = 0
last_action = None
cooldown = 1  # seconds

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 1)
        height, width, _ = frame.shape
        cx, cy = width // 2, height // 2

        # Define action zones (adjusted down zone)
        left_poly = np.array([[0, 0], [200, 150], [200, 340], [0, height - 1]], np.int32)
        right_poly = np.array([[width - 1, 0], [430, 150], [430, 340], [width - 1, height - 1]], np.int32)
        up_poly = np.array([[0, 0], [200, 150], [430, 150], [width - 1, 0]], np.int32)
        down_poly = np.array([[0, height - 1], [200, 340], [430, 340], [width - 1, height - 1]], np.int32)
        center_rect = (200, 150, 230, 190)  # x, y, w, h

        # Transparent overlay
        overlay = frame.copy()

        # Detect hands
        rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        result = hands.process(rgb)

        now = time.time()
        action = None

        if result.multi_hand_landmarks:
            for handLms in result.multi_hand_landmarks:
                mp_draw.draw_landmarks(frame, handLms, mp_hands.HAND_CONNECTIONS)

                # Get center of the hand
                lm = handLms.landmark[9]
                hand_x, hand_y = int(lm.x * width), int(lm.y * height)
                cv2.circle(frame, (hand_x, hand_y), 10, (255, 0, 0), -1)

                # Determine action zone
                if cv2.pointPolygonTest(left_poly, (hand_x, hand_y), False) >= 0:
                    action = 'left'
                    cv2.fillPoly(overlay, [left_poly], (0, 255, 255))
                elif cv2.pointPolygonTest(right_poly, (hand_x, hand_y), False) >= 0:
                    action = 'right'
                    cv2.fillPoly(overlay, [right_poly], (0, 255, 255))
                elif cv2.pointPolygonTest(up_poly, (hand_x, hand_y), False) >= 0:
                    action = 'up'
                    cv2.fillPoly(overlay, [up_poly], (0, 255, 255))
                elif cv2.pointPolygonTest(down_poly, (hand_x, hand_y), False) >= 0:
                    action = 'down'
                    cv2.fillPoly(overlay, [down_poly], (0, 255, 255))
                elif 200 <= hand_x <= 430 and 150 <= hand_y <= 340:
                    action = 'center'
                    cv2.rectangle(overlay, (200, 150), (430, 340), (0, 255, 255), -1)

        # Overlay with transparency
        alpha = 0.4
        frame = cv2.addWeighted(overlay, alpha, frame, 1 - alpha, 0)

        # Draw zone outlines
        cv2.rectangle(frame, (200, 150), (430, 340), (0, 255, 255), 2)
        cv2.polylines(frame, [left_poly], True, (0, 255, 255), 2)
        cv2.polylines(frame, [right_poly], True, (0, 255, 255), 2)
        cv2.polylines(frame, [up_poly], True, (0, 255, 255), 2)
        cv2.polylines(frame, [down_poly], True, (0, 255, 255), 2)

        # Draw labels
        cv2.putText(frame, "Center", (cx, cy + 80), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
        cv2.putText(frame, "Left", (30, cy + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)
        cv2.putText(frame, "Right", (width - 150, cy + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 255), 2)
        cv2.putText(frame, "Up", (cx + 60, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)
        cv2.putText(frame, "Down", (cx + 50, height - 40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

        # Perform action with cooldown
        if action and (now - last_action_time > cooldown or action != last_action):
            if action != 'center':
                pyautogui.press(action)
            print(f"Action: {action}")
            last_action_time = now
            last_action = action

        # Display frame
        cv2.imshow("Subway Surfer Gesture Control", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

except Exception as e:
    print(f"Error: {e}")
finally:
    cap.release()
    cv2.destroyAllWindows()
    print("Program exited.")
# Out:
# Action: center
# Action: up
# Action: center
# Action: right
# Action: center
# Action: up
# Action: center
# Action: center
# Action: center
# Action: down
# Action: center
# Action: down
# Action: center
# Action: left
# Action: center
# Action: down
# Action: center
# Action: center
# Action: right
# Action: center
# Action: left
# Action: center
# Action: up
# Action: center
# Action: right
# Action: center
# Action: down
# Action: center
# Action: left
# Action: center
# Action: right
# Action: right
# Action: center
# Action: down
# Action: down
# Action: down
# Action: down
# Action: center
# Action: up
# Action: up
# Action: up
# Action: center
# Action: center
# Action: left
# Action: left
# Action: center
# Action: left
# Action: center
# Action: center
# Action: center
# Action: center
# Action: right
# Action: center
# Action: up
# Action: center
# Action: down
# Action: center
# Action: center
# Action: right
# Action: right
# Action: center
# Action: up
# ...
